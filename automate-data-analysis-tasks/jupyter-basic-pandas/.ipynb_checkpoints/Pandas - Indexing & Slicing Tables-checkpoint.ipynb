# %%
# loc method = using label based (label name)
# iloc method = using position based (index)

# label based will inlcude the upper limit, while position based will not
# e.g. djson.loc['Luke':'John'] will have length = 4, while djson.iloc[0:3] will have length = 3 (index 3 not included)

# 3 operators for filtering data and boolean indexing: | (or), & (and), ~ (not)

# %%
import pandas

# %%
djson = pandas.read_json('./src/Employees.json') # read json file using read_json() function
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# 4    Instagram Ads
# 5  In-Person Sales
# 6  Warehouse Mgmt.
# 7     Online Sales
# 8    Linux Servers
# 9  Product Loading

# %%
# set column FirstName as label index
djson.set_index('FirstName', inplace = True)
djson
# Out:
#            ID  LastName Department       Phone              Address  Salary  \
# FirstName
# Luke        1   Phillip      Sales  1234567890   1st Address, Miami   52000
# Jack        2    Darren         IT  1234567891   2nd Address, Miami   52200
# Ken         3      Wood         IT  1234567892   3rd Address, Miami   58000
# John        4    Wilson  Marketing  1234567893   4th Address, Miami   58700
# Emily       5    Larson  Marketing  1234567894   5th Address, Miami   60000
# Anna        6  Sullivan      Sales  1234567895   6th Address, Miami   54000
# Richard     7     Smith  Logistics  1234567896   7th Address, Miami   56000
# Ronnie      8     Moore      Sales  1234567897   8th Address, Miami   49000
# Ron         9     Drake         IT  1234567898   9th Address, Miami   53000
# Wayne      10    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#                     Skills
# FirstName
# Luke          Online Sales
# Jack            Networking
# Ken           Python, Java
# John          Facebook Ads
# Emily        Instagram Ads
# Anna       In-Person Sales
# Richard    Warehouse Mgmt.
# Ronnie        Online Sales
# Ron          Linux Servers
# Wayne      Product Loading

# %%
djson.loc['John'] # print only 1 row
# Out:
# ID                             4
# LastName                  Wilson
# Department             Marketing
# Phone                 1234567893
# Address       4th Address, Miami
# Salary                     58700
# Skills              Facebook Ads
# Name: John, dtype: object

# %%
djson.loc[['John','Anna','Ron']] # print few rows based on label name
# Out:
#            ID  LastName Department       Phone             Address  Salary  \
# FirstName
# John        4    Wilson  Marketing  1234567893  4th Address, Miami   58700
# Anna        6  Sullivan      Sales  1234567895  6th Address, Miami   54000
# Ron         9     Drake         IT  1234567898  9th Address, Miami   53000
#
#                     Skills
# FirstName
# John          Facebook Ads
# Anna       In-Person Sales
# Ron          Linux Servers

# %%
djson.loc['Jack':'Emily'] # slicing based on label name
# Out:
#            ID LastName Department       Phone             Address  Salary  \
# FirstName
# Jack        2   Darren         IT  1234567891  2nd Address, Miami   52200
# Ken         3     Wood         IT  1234567892  3rd Address, Miami   58000
# John        4   Wilson  Marketing  1234567893  4th Address, Miami   58700
# Emily       5   Larson  Marketing  1234567894  5th Address, Miami   60000
#
#                   Skills
# FirstName
# Jack          Networking
# Ken         Python, Java
# John        Facebook Ads
# Emily      Instagram Ads

# %%
djson.loc['Luke':'John', "Phone":"Skills"] # slicing based on label index name & column name
# Out:
#                 Phone             Address  Salary        Skills
# FirstName
# Luke       1234567890  1st Address, Miami   52000  Online Sales
# Jack       1234567891  2nd Address, Miami   52200    Networking
# Ken        1234567892  3rd Address, Miami   58000  Python, Java
# John       1234567893  4th Address, Miami   58700  Facebook Ads

# %%
djson.loc['Ken':'Anna', ["Phone", "Skills", "Address"]] # slicing label index name & columns name
# Out:
#                 Phone           Skills             Address
# FirstName
# Ken        1234567892     Python, Java  3rd Address, Miami
# John       1234567893     Facebook Ads  4th Address, Miami
# Emily      1234567894    Instagram Ads  5th Address, Miami
# Anna       1234567895  In-Person Sales  6th Address, Miami

# %%
djson.loc['Ken', "Phone"] # print specific cell
# Out:
# 1234567892

# %%
djson.loc[:, "Phone"] # print phone column for all rows
# Out:
# FirstName
# Luke       1234567890
# Jack       1234567891
# Ken        1234567892
# John       1234567893
# Emily      1234567894
# Anna       1234567895
# Richard    1234567896
# Ronnie     1234567897
# Ron        1234567898
# Wayne      1234567899
# Name: Phone, dtype: int64

# %%
set(djson.loc[:, 'Department']) # print unique department by converting to set data type
# Out:
# {'IT', 'Logistics', 'Marketing', 'Sales'}

# %%
djson.iloc[0:3] # position based slicing using iloc will not return the upper limit
# Out:
#            ID LastName Department       Phone             Address  Salary  \
# FirstName
# Luke        1  Phillip      Sales  1234567890  1st Address, Miami   52000
# Jack        2   Darren         IT  1234567891  2nd Address, Miami   52200
# Ken         3     Wood         IT  1234567892  3rd Address, Miami   58000
#
#                  Skills
# FirstName
# Luke       Online Sales
# Jack         Networking
# Ken        Python, Java

# %%
djson.iloc[2, 2:5] # iloc method will not return address column as the upper limit
# Out:
# Department                    IT
# Phone                 1234567892
# Address       3rd Address, Miami
# Name: Ken, dtype: object

# %%
djson.sample() # return random sample
# Out:
#            ID LastName Department       Phone             Address  Salary  \
# FirstName
# Emily       5   Larson  Marketing  1234567894  5th Address, Miami   60000
#
#                   Skills
# FirstName
# Emily      Instagram Ads

# %%
djson.sample(n = 4) # return 4 random sample
# Out:
#            ID  LastName Department       Phone             Address  Salary  \
# FirstName
# John        4    Wilson  Marketing  1234567893  4th Address, Miami   58700
# Anna        6  Sullivan      Sales  1234567895  6th Address, Miami   54000
# Luke        1   Phillip      Sales  1234567890  1st Address, Miami   52000
# Jack        2    Darren         IT  1234567891  2nd Address, Miami   52200
#
#                     Skills
# FirstName
# John          Facebook Ads
# Anna       In-Person Sales
# Luke          Online Sales
# Jack            Networking

# %%
djson.sample(frac = 0.5) # return half / 50% random sample
# Out:
#            ID LastName Department       Phone              Address  Salary  \
# FirstName
# Wayne      10   Barker  Logistics  1234567899  10th Address, Miami   59500
# Emily       5   Larson  Marketing  1234567894   5th Address, Miami   60000
# Jack        2   Darren         IT  1234567891   2nd Address, Miami   52200
# Ken         3     Wood         IT  1234567892   3rd Address, Miami   58000
# Ron         9    Drake         IT  1234567898   9th Address, Miami   53000
#
#                     Skills
# FirstName
# Wayne      Product Loading
# Emily        Instagram Ads
# Jack            Networking
# Ken           Python, Java
# Ron          Linux Servers

# %%
djson = pandas.read_json('./src/Employees.json')
djson.set_index('ID', inplace = True)

# %%
djson[djson.loc[:,'Salary'] < 50000] # filtering data, return only those who has salary < 50000
# Out:
#    FirstName LastName Department       Phone             Address  Salary  \
# ID
# 8     Ronnie    Moore      Sales  1234567897  8th Address, Miami   49000
#
#           Skills
# ID
# 8   Online Sales

# %%
djson[(djson.loc[:,'Salary'] < 50000) | (djson.loc[:,'Salary'] > 56000)] # filtering data, return only those who has salary < 50000 OR salary > 56000
# Out:
#    FirstName LastName Department       Phone              Address  Salary  \
# ID
# 3        Ken     Wood         IT  1234567892   3rd Address, Miami   58000
# 4       John   Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5      Emily   Larson  Marketing  1234567894   5th Address, Miami   60000
# 8     Ronnie    Moore      Sales  1234567897   8th Address, Miami   49000
# 10     Wayne   Barker  Logistics  1234567899  10th Address, Miami   59500
#
#              Skills
# ID
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# 8      Online Sales
# 10  Product Loading

# %%
djson[(djson.loc[:,'Salary'] > 50000) & (djson.loc[:,'Department'] == 'Sales')] # filtering data, return only those who has salary > 50000 AND department = sales
# Out:
#    FirstName  LastName Department       Phone             Address  Salary  \
# ID
# 1       Luke   Phillip      Sales  1234567890  1st Address, Miami   52000
# 6       Anna  Sullivan      Sales  1234567895  6th Address, Miami   54000
#
#              Skills
# ID
# 1      Online Sales
# 6   In-Person Sales

# %%
djson[ ~ (djson.loc[:,'Department'] != 'IT')] # filtering data, return only those who work in IT department. Can use ~ or !=
# Out:
#    FirstName LastName Department       Phone             Address  Salary  \
# ID
# 2       Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 3        Ken     Wood         IT  1234567892  3rd Address, Miami   58000
# 9        Ron    Drake         IT  1234567898  9th Address, Miami   53000
#
#            Skills
# ID
# 2      Networking
# 3    Python, Java
# 9   Linux Servers
