# %%
# label based slicing = using loc method
# poisition based slicing = using iloc method
# the different is that label based will inlcude the end parameter, while position based will not
# e.g. djson.loc[0:3] will have length = 4, while djson.iloc[0:3] will have length = 3 (index 3 not included)

# 3 operators for filtering data and boolean indexing: | (or), & (and), ~ (not)

# %%
import pandas

# %%
djson = pandas.read_json('./src/Employees.json') # read json file using read_json() function
djson
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894   5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 6   7   Richard     Smith  Logistics  1234567896   7th Address, Miami   56000
# 7   8    Ronnie     Moore      Sales  1234567897   8th Address, Miami   49000
# 8   9       Ron     Drake         IT  1234567898   9th Address, Miami   53000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 0     Online Sales
# 1       Networking
# 2     Python, Java
# 3     Facebook Ads
# 4    Instagram Ads
# 5  In-Person Sales
# 6  Warehouse Mgmt.
# 7     Online Sales
# 8    Linux Servers
# 9  Product Loading

# %%
djson.loc[5] # print only 1 row
# Out:
# ID                             6
# FirstName                   Anna
# LastName                Sullivan
# Department                 Sales
# Phone                 1234567895
# Address       6th Address, Miami
# Salary                     54000
# Skills           In-Person Sales
# Name: 5, dtype: object

# %%
djson.loc[[2,5,9]] # print few rows based on index (indexing)
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 2   3       Ken      Wood         IT  1234567892   3rd Address, Miami   58000
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 2     Python, Java
# 5  In-Person Sales
# 9  Product Loading

# %%
djson.loc[3:5] # slicing index label
# Out:
#    ID FirstName  LastName Department       Phone             Address  Salary  \
# 3   4      John    Wilson  Marketing  1234567893  4th Address, Miami   58700
# 4   5     Emily    Larson  Marketing  1234567894  5th Address, Miami   60000
# 5   6      Anna  Sullivan      Sales  1234567895  6th Address, Miami   54000
#
#             Skills
# 3     Facebook Ads
# 4    Instagram Ads
# 5  In-Person Sales

# %%
djson.loc[0:2, "Phone":"Skills"] # slicing index label & column label
# Out:
#         Phone             Address  Salary        Skills
# 0  1234567890  1st Address, Miami   52000  Online Sales
# 1  1234567891  2nd Address, Miami   52200    Networking
# 2  1234567892  3rd Address, Miami   58000  Python, Java

# %%
djson.loc[3:6, ["Phone", "Skills", "Address"]] # slicing index label & indexing columns label
# Out:
#         Phone           Skills             Address
# 3  1234567893     Facebook Ads  4th Address, Miami
# 4  1234567894    Instagram Ads  5th Address, Miami
# 5  1234567895  In-Person Sales  6th Address, Miami
# 6  1234567896  Warehouse Mgmt.  7th Address, Miami

# %%
djson.loc[2, "Phone"] # print specific cell
# Out:
# 1234567892

# %%
djson.loc[:, "Phone"] # print phone column for all rows
# Out:
# 0    1234567890
# 1    1234567891
# 2    1234567892
# 3    1234567893
# 4    1234567894
# 5    1234567895
# 6    1234567896
# 7    1234567897
# 8    1234567898
# 9    1234567899
# Name: Phone, dtype: int64

# %%
set(djson.loc[:, 'Department']) # print unique department by converting to set data type
# Out:
# {'IT', 'Logistics', 'Marketing', 'Sales'}

# %%
djson.iloc[0:3] # position based slicing using iloc will not return the last index
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 0   1      Luke  Phillip      Sales  1234567890  1st Address, Miami   52000
# 1   2      Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 2   3       Ken     Wood         IT  1234567892  3rd Address, Miami   58000
#
#          Skills
# 0  Online Sales
# 1    Networking
# 2  Python, Java

# %%
djson.iloc[2, 2:5] # iloc method will not return address column as the last index
# Out:
# LastName            Wood
# Department            IT
# Phone         1234567892
# Name: 2, dtype: object

# %%
djson.sample() # return random sample
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 8   9       Ron    Drake         IT  1234567898  9th Address, Miami   53000
#
#           Skills
# 8  Linux Servers

# %%
djson.sample(n = 4) # return 4 random sample
# Out:
#    ID FirstName LastName Department       Phone             Address  Salary  \
# 4   5     Emily   Larson  Marketing  1234567894  5th Address, Miami   60000
# 0   1      Luke  Phillip      Sales  1234567890  1st Address, Miami   52000
# 1   2      Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 2   3       Ken     Wood         IT  1234567892  3rd Address, Miami   58000
#
#           Skills
# 4  Instagram Ads
# 0   Online Sales
# 1     Networking
# 2   Python, Java

# %%
djson.sample(frac = 0.5) # return half / 50% random sample
# Out:
#    ID FirstName  LastName Department       Phone              Address  Salary  \
# 1   2      Jack    Darren         IT  1234567891   2nd Address, Miami   52200
# 3   4      John    Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5   6      Anna  Sullivan      Sales  1234567895   6th Address, Miami   54000
# 0   1      Luke   Phillip      Sales  1234567890   1st Address, Miami   52000
# 9  10     Wayne    Barker  Logistics  1234567899  10th Address, Miami   59500
#
#             Skills
# 1       Networking
# 3     Facebook Ads
# 5  In-Person Sales
# 0     Online Sales
# 9  Product Loading

# %%
djson = pandas.read_json('./src/Employees.json')
djson.set_index('ID', inplace = True)

# %%
djson[djson.loc[:,'Salary'] < 50000] # filtering data, return only those who has salary < 50000
# Out:
#    FirstName LastName Department       Phone             Address  Salary  \
# ID
# 8     Ronnie    Moore      Sales  1234567897  8th Address, Miami   49000
#
#           Skills
# ID
# 8   Online Sales

# %%
djson[(djson.loc[:,'Salary'] < 50000) | (djson.loc[:,'Salary'] > 56000)] # filtering data, return only those who has salary < 50000 OR salary > 56000
# Out:
#    FirstName LastName Department       Phone              Address  Salary  \
# ID
# 3        Ken     Wood         IT  1234567892   3rd Address, Miami   58000
# 4       John   Wilson  Marketing  1234567893   4th Address, Miami   58700
# 5      Emily   Larson  Marketing  1234567894   5th Address, Miami   60000
# 8     Ronnie    Moore      Sales  1234567897   8th Address, Miami   49000
# 10     Wayne   Barker  Logistics  1234567899  10th Address, Miami   59500
#
#              Skills
# ID
# 3      Python, Java
# 4      Facebook Ads
# 5     Instagram Ads
# 8      Online Sales
# 10  Product Loading

# %%
djson[(djson.loc[:,'Salary'] > 50000) & (djson.loc[:,'Department'] == 'Sales')] # filtering data, return only those who has salary > 50000 AND department = sales
# Out:
#    FirstName  LastName Department       Phone             Address  Salary  \
# ID
# 1       Luke   Phillip      Sales  1234567890  1st Address, Miami   52000
# 6       Anna  Sullivan      Sales  1234567895  6th Address, Miami   54000
#
#              Skills
# ID
# 1      Online Sales
# 6   In-Person Sales

# %%
djson[ ~ (djson.loc[:,'Department'] != 'IT')] # filtering data, return only those who work in IT department. Can use ~ or !=
# Out:
#    FirstName LastName Department       Phone             Address  Salary  \
# ID
# 2       Jack   Darren         IT  1234567891  2nd Address, Miami   52200
# 3        Ken     Wood         IT  1234567892  3rd Address, Miami   58000
# 9        Ron    Drake         IT  1234567898  9th Address, Miami   53000
#
#            Skills
# ID
# 2      Networking
# 3    Python, Java
# 9   Linux Servers
